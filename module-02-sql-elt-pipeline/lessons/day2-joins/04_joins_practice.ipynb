# %% [markdown]
# # Day 2: SQL JOINs — Interactive Practice
#
# ## Objective
# Learn how to combine data from multiple tables using SQL JOINs. By the end of this notebook, you will be comfortable writing `INNER JOIN`, `LEFT JOIN`, `RIGHT JOIN`, `FULL OUTER JOIN`, self-joins, and multi-table joins.
#
# ## Table of Contents
# 1. [Connection Setup](#connection-setup)
# 2. [INNER JOIN — Only Matching Rows](#inner-join--only-matching-rows)
# 3. [LEFT JOIN — Keep All Rows from the Left](#left-join--keep-all-rows-from-the-left)
# 4. [Filtering with Joins — Finding Orphan Records](#filtering-with-joins--finding-orphan-records)
# 5. [RIGHT JOIN — The Mirror Image](#right-join--the-mirror-image)
# 6. [FULL OUTER JOIN — Everything from Both Sides](#full-outer-join--everything-from-both-sides)
# 7. [Self-Join — The Manager Hierarchy](#self-join--the-manager-hierarchy)
# 8. [Multi-Table Join — employees → departments → sales → products](#multi-table-join--employees--departments--sales--products)
# 9. [Try It Yourself Exercises](#try-it-yourself-exercises)

# %% [markdown]
# ## Connection Setup
#
# We use the same `run_query` helper from Day 1. It connects to the PostgreSQL database, executes a query, returns results as a pandas DataFrame, and always closes the connection.
#
# **Tables we will use today:**
# - `company.employees` — emp_id, first_name, last_name, email, department_id, salary, hire_date, manager_id, is_active
# - `company.departments` — dept_id, dept_name, location
# - `company.sales` — sale_id, employee_id, product_id, quantity, sale_date
# - `company.products` — product_id, product_name, unit_price, category

# %%
import psycopg2
import pandas as pd

def run_query(sql: str) -> pd.DataFrame:
    """Run a SQL query and return results as a DataFrame."""
    conn = psycopg2.connect(
        host="localhost", port=5432,
        dbname="week2_db", user="student", password="student123"
    )
    try:
        df = pd.read_sql_query(sql, conn)
        return df
    finally:
        conn.close()

print("Helper function defined. Ready for JOINs!")
# Out:
# Helper function defined. Ready for JOINs!

# %% [markdown]
# Let's quickly remind ourselves of the two tables we will join first. Always inspect your tables before writing a JOIN — it helps you predict the result.

# %%
# Quick peek: employees (just the columns relevant for our join)
run_query("""
    SELECT emp_id, first_name, last_name, department_id 
    FROM company.employees 
    ORDER BY emp_id 
    LIMIT 10
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    emp_id first_name last_name  department_id
# 0       1      Alice      Chen              1
# 1       2        Bob  Martinez              1
# 2       3      Carol   Johnson              1
# 3       4      David       Kim              1
# 4       5        Eva     Patel              1
# 5       6      Frank    Wilson              1
# 6       7      Grace       Lee              1
# 7       8       Hank     Brown              1
# 8       9       Iris    Taylor              2
# 9      10       Jack  Anderson              2

# %% [markdown]
# **Expected output:** 10 rows showing emp_id, first_name, last_name, and department_id. Notice that some employees have department_id = 1 (Engineering), some = 2 (HR), etc. Also check if any have `NULL`.

# %%
# Quick peek: departments
run_query("""
    SELECT * FROM company.departments 
    ORDER BY dept_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    dept_id        dept_name    location     budget
# 0        1      Engineering  Building A  2500000.0
# 1        2  Human Resources  Building B   800000.0
# 2        3          Finance  Building C  1200000.0
# 3        4        Marketing  Building D   950000.0
# 4        5            Sales  Building E  1800000.0
# 5        6       Operations  Building F  1100000.0

# %% [markdown]
# **Expected output:** All departments with their dept_id, dept_name, and location. This is a small table (around 6 departments). Note which department IDs exist.

# %% [markdown]
# ## INNER JOIN — Only Matching Rows
#
# An `INNER JOIN` returns **only rows where the join key matches in both tables**. If an employee has no department, or a department_id that doesn't exist in the departments table, that employee will **not appear** in the result.
#
# **Plain English:** "Show me employees alongside their department name — but only if they actually belong to a department."
#
# **Syntax note:** `JOIN` without a qualifier means `INNER JOIN`. They are identical.

# %%
# INNER JOIN: employees + departments
run_query("""
    SELECT 
        e.emp_id,
        e.first_name,
        e.last_name,
        e.department_id,
        d.dept_name,
        d.location
    FROM company.employees e
    INNER JOIN company.departments d 
        ON e.department_id = d.dept_id
    ORDER BY e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id first_name last_name  department_id        dept_name    location
# 0        1      Alice      Chen              1      Engineering  Building A
# 1        2        Bob  Martinez              1      Engineering  Building A
# 2        3      Carol   Johnson              1      Engineering  Building A
# 3        4      David       Kim              1      Engineering  Building A
# 4        5        Eva     Patel              1      Engineering  Building A
# 5        6      Frank    Wilson              1      Engineering  Building A
# 6        7      Grace       Lee              1      Engineering  Building A
# 7        8       Hank     Brown              1      Engineering  Building A
# 8        9       Iris    Taylor              2  Human Resources  Building B
# 9       10       Jack  Anderson              2  Human Resources  Building B
# 10      11      Karen    Thomas              2  Human Resources  Building B
# 11      12        Leo   Jackson              2  Human Resources  Building B
# 12      13      Maria     White              2  Human Resources  Building B
# 13      14     Nathan    Harris              3          Finance  Building C
# 14      15     Olivia     Clark              3          Finance  Building C
# 15      16      Peter     Lewis              3          Finance  Building C
# 16      17      Quinn    Walker              3          Finance  Building C
# 17      18     Rachel      Hall              3          Finance  Building C
# 18      19        Sam     Allen              3          Finance  Building C
# 19      20       Tina     Young              3          Finance  Building C
# 20      21        Uma      King              4        Marketing  Building D
# 21      22     Victor    Wright              4        Marketing  Building D
# 22      23      Wendy     Lopez              4        Marketing  Building D
# 23      24     Xavier      Hill              4        Marketing  Building D
# 24      25       Yara     Scott              4        Marketing  Building D
# 25      26       Zane     Green              4        Marketing  Building D
# 26      27        Amy     Adams              5            Sales  Building E
# 27      28      Brian     Baker              5            Sales  Building E
# 28      29      Cindy    Nelson              5            Sales  Building E
# 29      30      Derek    Carter              5            Sales  Building E
# 30      31       Emma  Mitchell              5            Sales  Building E
# 31      32      Felix     Perez              5            Sales  Building E
# 32      33       Gina   Roberts              5            Sales  Building E
# 33      34      Henry    Turner              5            Sales  Building E
# 34      35        Ivy  Phillips              5            Sales  Building E
# 35      36      James  Campbell              6       Operations  Building F
# 36      37      Kelly    Parker              6       Operations  Building F
# 37      38       Liam     Evans              6       Operations  Building F
# 38      39        Mia   Edwards              6       Operations  Building F
# 39      40       Noah   Collins              6       Operations  Building F
# 40      41      Oscar   Stewart              6       Operations  Building F

# %% [markdown]
# **Expected output:** Employees with valid departments only. Each row shows the employee's info alongside their department name and location. Employees with `NULL` department_id or invalid department_ids will be missing.

# %% [markdown]
# ### How many rows did we lose?
#
# Let's count the employees before and after the join to see exactly how many rows disappeared.

# %%
# Count total employees (before join)
run_query("""
    SELECT COUNT(*) AS total_employees 
    FROM company.employees
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    total_employees
# 0               42

# %% [markdown]
# **Expected output:** A single number (around 30 employees total).

# %%
# Count employees with matching departments (after INNER JOIN)
run_query("""
    SELECT COUNT(*) AS matched_employees
    FROM company.employees e
    INNER JOIN company.departments d 
        ON e.department_id = d.dept_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    matched_employees
# 0                 41

# %% [markdown]
# **Expected output:** A number smaller than the total. The difference tells you how many employees have no valid department.
#
# **Key insight:** If `total_employees - matched_employees > 0`, those missing employees have either `NULL` as their `department_id` or a department_id that doesn't exist in the departments table. INNER JOIN silently dropped them!

# %%
# Let's see who got dropped: employees without a valid department
run_query("""
    SELECT emp_id, first_name, last_name, department_id
    FROM company.employees
    WHERE department_id IS NULL 
       OR department_id NOT IN (SELECT dept_id FROM company.departments)
    ORDER BY emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    emp_id first_name last_name department_id
# 0      42      Paula    Morris          None

# %% [markdown]
# **Expected output:** The employees that disappeared from the INNER JOIN. Likely Paula Morris (department_id = NULL) and possibly others with invalid department references. This is why INNER JOIN can be dangerous for reports — you might not realize you're missing people!

# %% [markdown]
# ## LEFT JOIN — Keep All Rows from the Left
#
# A `LEFT JOIN` returns **ALL rows from the left table** (the one after `FROM`), plus matching rows from the right table. Where no match exists, the right-side columns are filled with `NULL`.
#
# **Plain English:** "Show me ALL employees, and their department name if they have one."
#
# **Why LEFT JOIN is the default in real work:** You rarely want to silently lose data. If a new employee hasn't been assigned a department yet, you still want to see them in your report.

# %%
# LEFT JOIN: ALL employees, with department info when available
run_query("""
    SELECT 
        e.emp_id,
        e.first_name,
        e.last_name,
        e.department_id,
        d.dept_name,
        d.location
    FROM company.employees e
    LEFT JOIN company.departments d 
        ON e.department_id = d.dept_id
    ORDER BY e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id first_name last_name  department_id        dept_name    location
# 0        1      Alice      Chen            1.0      Engineering  Building A
# 1        2        Bob  Martinez            1.0      Engineering  Building A
# 2        3      Carol   Johnson            1.0      Engineering  Building A
# 3        4      David       Kim            1.0      Engineering  Building A
# 4        5        Eva     Patel            1.0      Engineering  Building A
# 5        6      Frank    Wilson            1.0      Engineering  Building A
# 6        7      Grace       Lee            1.0      Engineering  Building A
# 7        8       Hank     Brown            1.0      Engineering  Building A
# 8        9       Iris    Taylor            2.0  Human Resources  Building B
# 9       10       Jack  Anderson            2.0  Human Resources  Building B
# 10      11      Karen    Thomas            2.0  Human Resources  Building B
# 11      12        Leo   Jackson            2.0  Human Resources  Building B
# 12      13      Maria     White            2.0  Human Resources  Building B
# 13      14     Nathan    Harris            3.0          Finance  Building C
# 14      15     Olivia     Clark            3.0          Finance  Building C
# 15      16      Peter     Lewis            3.0          Finance  Building C
# 16      17      Quinn    Walker            3.0          Finance  Building C
# 17      18     Rachel      Hall            3.0          Finance  Building C
# 18      19        Sam     Allen            3.0          Finance  Building C
# 19      20       Tina     Young            3.0          Finance  Building C
# 20      21        Uma      King            4.0        Marketing  Building D
# 21      22     Victor    Wright            4.0        Marketing  Building D
# 22      23      Wendy     Lopez            4.0        Marketing  Building D
# 23      24     Xavier      Hill            4.0        Marketing  Building D
# 24      25       Yara     Scott            4.0        Marketing  Building D
# 25      26       Zane     Green            4.0        Marketing  Building D
# 26      27        Amy     Adams            5.0            Sales  Building E
# 27      28      Brian     Baker            5.0            Sales  Building E
# 28      29      Cindy    Nelson            5.0            Sales  Building E
# 29      30      Derek    Carter            5.0            Sales  Building E
# 30      31       Emma  Mitchell            5.0            Sales  Building E
# 31      32      Felix     Perez            5.0            Sales  Building E
# 32      33       Gina   Roberts            5.0            Sales  Building E
# 33      34      Henry    Turner            5.0            Sales  Building E
# 34      35        Ivy  Phillips            5.0            Sales  Building E
# 35      36      James  Campbell            6.0       Operations  Building F
# 36      37      Kelly    Parker            6.0       Operations  Building F
# 37      38       Liam     Evans            6.0       Operations  Building F
# 38      39        Mia   Edwards            6.0       Operations  Building F
# 39      40       Noah   Collins            6.0       Operations  Building F
# 40      41      Oscar   Stewart            6.0       Operations  Building F
# 41      42      Paula    Morris            NaN              NaN         NaN

# %% [markdown]
# **Expected output:** ALL employees appear (same count as `total_employees` from earlier). Most will have dept_name and location filled in. The employees without a valid department will show `NULL` in the dept_name and location columns.
#
# **Compare with the INNER JOIN result:** The INNER JOIN had fewer rows. The LEFT JOIN has everyone. The rows that were missing from INNER JOIN now appear with NULL values on the right side.

# %%
# Verify: COUNT should match total_employees from earlier
run_query("""
    SELECT COUNT(*) AS all_employees_count
    FROM company.employees e
    LEFT JOIN company.departments d 
        ON e.department_id = d.dept_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    all_employees_count
# 0                   42

# %% [markdown]
# **Expected output:** Same number as `total_employees` from the count earlier. This proves LEFT JOIN preserves all left-table rows.
#
# **Understanding NULL in LEFT JOIN:** When there's no matching row on the right side, PostgreSQL fills those columns with NULL. This is not an error — it means "this employee doesn't have a department." You can use these NULLs to find problems in your data (we'll do that next).

# %% [markdown]
# ## Filtering with Joins — Finding Orphan Records
#
# One of the most practical uses of LEFT JOIN is finding **orphan records** — rows on the left side that have no match on the right. This is a powerful data quality check.
#
# **Pattern:** LEFT JOIN + `WHERE right_table.column IS NULL`
#
# **Plain English:** "Show me employees who don't belong to any department."

# %%
# Find employees without a valid department
run_query("""
    SELECT 
        e.emp_id,
        e.first_name,
        e.last_name,
        e.department_id
    FROM company.employees e
    LEFT JOIN company.departments d 
        ON e.department_id = d.dept_id
    WHERE d.dept_id IS NULL
    ORDER BY e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    emp_id first_name last_name department_id
# 0      42      Paula    Morris          None

# %% [markdown]
# **Expected output:** Only the employees with no matching department. This is a much smaller list than the full LEFT JOIN result. These are your "orphan" records.
#
# **Why this works:** The LEFT JOIN first includes ALL employees. Then the WHERE clause filters to only those rows where `d.dept_id` ended up as NULL — meaning no match was found. This is the classic pattern for finding data quality issues.
#
# **Real-world use cases:**
# - Find orders with no customer
# - Find products with no category
# - Find students with no enrolled course
# - Find sales transactions with no assigned salesperson

# %% [markdown]
# ## RIGHT JOIN — The Mirror Image
#
# A `RIGHT JOIN` is a LEFT JOIN with the tables swapped. It keeps ALL rows from the **right** table (the one after `JOIN`), and matches from the left.
#
# **Practical tip:** RIGHT JOIN is almost never used in practice. Just swap the table order and use LEFT JOIN instead — it's more readable.
#
# Let's prove they produce the same result.

# %%
# RIGHT JOIN: ALL departments, with employees when they exist
run_query("""
    SELECT 
        e.emp_id,
        e.first_name,
        e.last_name,
        d.dept_id,
        d.dept_name
    FROM company.employees e
    RIGHT JOIN company.departments d 
        ON e.department_id = d.dept_id
    ORDER BY d.dept_id, e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id first_name last_name  dept_id        dept_name
# 0        1      Alice      Chen        1      Engineering
# 1        2        Bob  Martinez        1      Engineering
# 2        3      Carol   Johnson        1      Engineering
# 3        4      David       Kim        1      Engineering
# 4        5        Eva     Patel        1      Engineering
# 5        6      Frank    Wilson        1      Engineering
# 6        7      Grace       Lee        1      Engineering
# 7        8       Hank     Brown        1      Engineering
# 8        9       Iris    Taylor        2  Human Resources
# 9       10       Jack  Anderson        2  Human Resources
# 10      11      Karen    Thomas        2  Human Resources
# 11      12        Leo   Jackson        2  Human Resources
# 12      13      Maria     White        2  Human Resources
# 13      14     Nathan    Harris        3          Finance
# 14      15     Olivia     Clark        3          Finance
# 15      16      Peter     Lewis        3          Finance
# 16      17      Quinn    Walker        3          Finance
# 17      18     Rachel      Hall        3          Finance
# 18      19        Sam     Allen        3          Finance
# 19      20       Tina     Young        3          Finance
# 20      21        Uma      King        4        Marketing
# 21      22     Victor    Wright        4        Marketing
# 22      23      Wendy     Lopez        4        Marketing
# 23      24     Xavier      Hill        4        Marketing
# 24      25       Yara     Scott        4        Marketing
# 25      26       Zane     Green        4        Marketing
# 26      27        Amy     Adams        5            Sales
# 27      28      Brian     Baker        5            Sales
# 28      29      Cindy    Nelson        5            Sales
# 29      30      Derek    Carter        5            Sales
# 30      31       Emma  Mitchell        5            Sales
# 31      32      Felix     Perez        5            Sales
# 32      33       Gina   Roberts        5            Sales
# 33      34      Henry    Turner        5            Sales
# 34      35        Ivy  Phillips        5            Sales
# 35      36      James  Campbell        6       Operations
# 36      37      Kelly    Parker        6       Operations
# 37      38       Liam     Evans        6       Operations
# 38      39        Mia   Edwards        6       Operations
# 39      40       Noah   Collins        6       Operations
# 40      41      Oscar   Stewart        6       Operations

# %% [markdown]
# **Expected output:** ALL departments appear. Most will have employees listed. If any department has no employees, those rows will show NULL for emp_id, first_name, and last_name.

# %%
# Equivalent LEFT JOIN (tables swapped): Same result, more readable
run_query("""
    SELECT 
        e.emp_id,
        e.first_name,
        e.last_name,
        d.dept_id,
        d.dept_name
    FROM company.departments d
    LEFT JOIN company.employees e 
        ON e.department_id = d.dept_id
    ORDER BY d.dept_id, e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id first_name last_name  dept_id        dept_name
# 0        1      Alice      Chen        1      Engineering
# 1        2        Bob  Martinez        1      Engineering
# 2        3      Carol   Johnson        1      Engineering
# 3        4      David       Kim        1      Engineering
# 4        5        Eva     Patel        1      Engineering
# 5        6      Frank    Wilson        1      Engineering
# 6        7      Grace       Lee        1      Engineering
# 7        8       Hank     Brown        1      Engineering
# 8        9       Iris    Taylor        2  Human Resources
# 9       10       Jack  Anderson        2  Human Resources
# 10      11      Karen    Thomas        2  Human Resources
# 11      12        Leo   Jackson        2  Human Resources
# 12      13      Maria     White        2  Human Resources
# 13      14     Nathan    Harris        3          Finance
# 14      15     Olivia     Clark        3          Finance
# 15      16      Peter     Lewis        3          Finance
# 16      17      Quinn    Walker        3          Finance
# 17      18     Rachel      Hall        3          Finance
# 18      19        Sam     Allen        3          Finance
# 19      20       Tina     Young        3          Finance
# 20      21        Uma      King        4        Marketing
# 21      22     Victor    Wright        4        Marketing
# 22      23      Wendy     Lopez        4        Marketing
# 23      24     Xavier      Hill        4        Marketing
# 24      25       Yara     Scott        4        Marketing
# 25      26       Zane     Green        4        Marketing
# 26      27        Amy     Adams        5            Sales
# 27      28      Brian     Baker        5            Sales
# 28      29      Cindy    Nelson        5            Sales
# 29      30      Derek    Carter        5            Sales
# 30      31       Emma  Mitchell        5            Sales
# 31      32      Felix     Perez        5            Sales
# 32      33       Gina   Roberts        5            Sales
# 33      34      Henry    Turner        5            Sales
# 34      35        Ivy  Phillips        5            Sales
# 35      36      James  Campbell        6       Operations
# 36      37      Kelly    Parker        6       Operations
# 37      38       Liam     Evans        6       Operations
# 38      39        Mia   Edwards        6       Operations
# 39      40       Noah   Collins        6       Operations
# 40      41      Oscar   Stewart        6       Operations

# %% [markdown]
# **Expected output:** Identical to the RIGHT JOIN above. The only difference is the column order (dept_id/dept_name come first now because `departments` is the left table).
#
# **Takeaway:** `A RIGHT JOIN B` = `B LEFT JOIN A`. Just swap the tables and use LEFT JOIN. Most teams never use RIGHT JOIN in production code.

# %% [markdown]
# ## FULL OUTER JOIN — Everything from Both Sides
#
# A `FULL OUTER JOIN` returns **ALL rows from both tables**. Matched rows get combined. Unmatched rows from either side appear with NULLs on the other side.
#
# **Plain English:** "Show me ALL employees (even without departments) AND all departments (even without employees)."
#
# **Use case:** A comprehensive audit — finding every unmatched record on both sides at once.

# %%
# FULL OUTER JOIN: every employee and every department
run_query("""
    SELECT 
        e.emp_id,
        e.first_name,
        e.last_name,
        e.department_id,
        d.dept_id,
        d.dept_name,
        d.location
    FROM company.employees e
    FULL OUTER JOIN company.departments d 
        ON e.department_id = d.dept_id
    ORDER BY 
        CASE WHEN e.emp_id IS NULL THEN 1 ELSE 0 END,
        e.emp_id,
        d.dept_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id first_name last_name  department_id  dept_id        dept_name  \
# 0        1      Alice      Chen            1.0      1.0      Engineering
# 1        2        Bob  Martinez            1.0      1.0      Engineering
# 2        3      Carol   Johnson            1.0      1.0      Engineering
# 3        4      David       Kim            1.0      1.0      Engineering
# 4        5        Eva     Patel            1.0      1.0      Engineering
# 5        6      Frank    Wilson            1.0      1.0      Engineering
# 6        7      Grace       Lee            1.0      1.0      Engineering
# 7        8       Hank     Brown            1.0      1.0      Engineering
# 8        9       Iris    Taylor            2.0      2.0  Human Resources
# 9       10       Jack  Anderson            2.0      2.0  Human Resources
# 10      11      Karen    Thomas            2.0      2.0  Human Resources
# 11      12        Leo   Jackson            2.0      2.0  Human Resources
# 12      13      Maria     White            2.0      2.0  Human Resources
# 13      14     Nathan    Harris            3.0      3.0          Finance
# 14      15     Olivia     Clark            3.0      3.0          Finance
# 15      16      Peter     Lewis            3.0      3.0          Finance
# 16      17      Quinn    Walker            3.0      3.0          Finance
# 17      18     Rachel      Hall            3.0      3.0          Finance
# 18      19        Sam     Allen            3.0      3.0          Finance
# 19      20       Tina     Young            3.0      3.0          Finance
# 20      21        Uma      King            4.0      4.0        Marketing
# 21      22     Victor    Wright            4.0      4.0        Marketing
# 22      23      Wendy     Lopez            4.0      4.0        Marketing
# 23      24     Xavier      Hill            4.0      4.0        Marketing
# 24      25       Yara     Scott            4.0      4.0        Marketing
# 25      26       Zane     Green            4.0      4.0        Marketing
# 26      27        Amy     Adams            5.0      5.0            Sales
# 27      28      Brian     Baker            5.0      5.0            Sales
# 28      29      Cindy    Nelson            5.0      5.0            Sales
# 29      30      Derek    Carter            5.0      5.0            Sales
# 30      31       Emma  Mitchell            5.0      5.0            Sales
# 31      32      Felix     Perez            5.0      5.0            Sales
# 32      33       Gina   Roberts            5.0      5.0            Sales
# 33      34      Henry    Turner            5.0      5.0            Sales
# 34      35        Ivy  Phillips            5.0      5.0            Sales
# 35      36      James  Campbell            6.0      6.0       Operations
# 36      37      Kelly    Parker            6.0      6.0       Operations
# 37      38       Liam     Evans            6.0      6.0       Operations
# 38      39        Mia   Edwards            6.0      6.0       Operations
# 39      40       Noah   Collins            6.0      6.0       Operations
# 40      41      Oscar   Stewart            6.0      6.0       Operations
# 41      42      Paula    Morris            NaN      NaN              NaN
#
#       location
# 0   Building A
# 1   Building A
# 2   Building A
# 3   Building A
# 4   Building A
# 5   Building A
# 6   Building A
# 7   Building A
# 8   Building B
# 9   Building B
# 10  Building B
# 11  Building B
# 12  Building B
# 13  Building C
# 14  Building C
# 15  Building C
# 16  Building C
# 17  Building C
# 18  Building C
# 19  Building C
# 20  Building D
# 21  Building D
# 22  Building D
# 23  Building D
# 24  Building D
# 25  Building D
# 26  Building E
# 27  Building E
# 28  Building E
# 29  Building E
# 30  Building E
# 31  Building E
# 32  Building E
# 33  Building E
# 34  Building E
# 35  Building F
# 36  Building F
# 37  Building F
# 38  Building F
# 39  Building F
# 40  Building F
# 41         NaN

# %% [markdown]
# **Expected output:**
# - Most rows: employees with their departments (both sides filled)
# - Some rows: employees with NULL dept_name (employee has no valid department)
# - Possibly some rows: NULL emp_id with a dept_name (department has no employees)
#
# **The ORDER BY trick:** `CASE WHEN e.emp_id IS NULL THEN 1 ELSE 0 END` pushes unmatched departments (where emp_id is NULL) to the bottom so you can easily see them.
#
# **Key insight:** FULL OUTER JOIN = LEFT JOIN results + RIGHT JOIN results, combined and deduplicated. It's the most inclusive join type.

# %%
# Use case: Find ALL unmatched records from both sides
run_query("""
    SELECT 
        e.emp_id,
        e.first_name,
        e.last_name,
        d.dept_name,
        d.location,
        CASE 
            WHEN e.emp_id IS NULL THEN 'Department has no employees'
            WHEN d.dept_id IS NULL THEN 'Employee has no department'
        END AS issue_type
    FROM company.employees e
    FULL OUTER JOIN company.departments d 
        ON e.department_id = d.dept_id
    WHERE e.emp_id IS NULL 
       OR d.dept_id IS NULL
    ORDER BY issue_type, e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#    emp_id first_name last_name dept_name location                  issue_type
# 0      42      Paula    Morris      None     None  Employee has no department

# %% [markdown]
# **Expected output:** Only the problematic rows, with a clear `issue_type` label telling you whether it's an employee without a department or a department without employees. This is a handy data quality report.

# %% [markdown]
# ## Self-Join — The Manager Hierarchy
#
# A **self-join** joins a table to itself. This is useful for hierarchical data, like employees and their managers — where both are stored in the same `employees` table.
#
# **How it works:** The `employees` table has a `manager_id` column that points to another employee's `emp_id`. We join `employees AS e` (the worker) to `employees AS m` (the manager).
#
# **Why aliases are mandatory:** When the same table appears twice, you MUST use aliases so PostgreSQL knows which instance you mean. `e.first_name` is the employee's name, `m.first_name` is the manager's name.

# %%
# Self-join: Show each employee alongside their manager's name
run_query("""
    SELECT 
        e.emp_id,
        e.first_name || ' ' || e.last_name AS employee_name,
        e.department_id,
        m.first_name || ' ' || m.last_name AS manager_name
    FROM company.employees e
    INNER JOIN company.employees m 
        ON e.manager_id = m.emp_id
    ORDER BY e.emp_id
    LIMIT 20
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id  employee_name  department_id   manager_name
# 0        2   Bob Martinez              1     Alice Chen
# 1        3  Carol Johnson              1   Bob Martinez
# 2        4      David Kim              1   Bob Martinez
# 3        5      Eva Patel              1   Bob Martinez
# 4        6   Frank Wilson              1   Bob Martinez
# 5        7      Grace Lee              1   Bob Martinez
# 6        8     Hank Brown              1   Bob Martinez
# 7       10  Jack Anderson              2    Iris Taylor
# 8       11   Karen Thomas              2  Jack Anderson
# 9       12    Leo Jackson              2  Jack Anderson
# 10      13    Maria White              2  Jack Anderson
# 11      15   Olivia Clark              3    Maria White
# 12      16    Peter Lewis              3  Nathan Harris
# 13      17   Quinn Walker              3  Nathan Harris
# 14      18    Rachel Hall              3  Nathan Harris
# 15      19      Sam Allen              3  Nathan Harris
# 16      20     Tina Young              3  Nathan Harris
# 17      22  Victor Wright              4     Tina Young
# 18      23    Wendy Lopez              4       Uma King
# 19      24    Xavier Hill              4       Uma King

# %% [markdown]
# **Expected output:** Most employees with their manager's full name. For example, Bob Martinez → Alice Chen (Bob's manager is Alice). Directors with `manager_id = NULL` will NOT appear because INNER JOIN requires a match.
#
# **The `||` operator:** This is PostgreSQL string concatenation. `first_name || ' ' || last_name` joins the first name, a space, and the last name into one string.

# %%
# LEFT JOIN version: Include directors who have no manager
run_query("""
    SELECT 
        e.emp_id,
        e.first_name || ' ' || e.last_name AS employee_name,
        m.first_name || ' ' || m.last_name AS manager_name
    FROM company.employees e
    LEFT JOIN company.employees m 
        ON e.manager_id = m.emp_id
    ORDER BY e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id   employee_name    manager_name
# 0        1      Alice Chen             NaN
# 1        2    Bob Martinez      Alice Chen
# 2        3   Carol Johnson    Bob Martinez
# 3        4       David Kim    Bob Martinez
# 4        5       Eva Patel    Bob Martinez
# 5        6    Frank Wilson    Bob Martinez
# 6        7       Grace Lee    Bob Martinez
# 7        8      Hank Brown    Bob Martinez
# 8        9     Iris Taylor             NaN
# 9       10   Jack Anderson     Iris Taylor
# 10      11    Karen Thomas   Jack Anderson
# 11      12     Leo Jackson   Jack Anderson
# 12      13     Maria White   Jack Anderson
# 13      14   Nathan Harris             NaN
# 14      15    Olivia Clark     Maria White
# 15      16     Peter Lewis   Nathan Harris
# 16      17    Quinn Walker   Nathan Harris
# 17      18     Rachel Hall   Nathan Harris
# 18      19       Sam Allen   Nathan Harris
# 19      20      Tina Young   Nathan Harris
# 20      21        Uma King             NaN
# 21      22   Victor Wright      Tina Young
# 22      23     Wendy Lopez        Uma King
# 23      24     Xavier Hill        Uma King
# 24      25      Yara Scott        Uma King
# 25      26      Zane Green        Uma King
# 26      27       Amy Adams             NaN
# 27      28     Brian Baker       Amy Adams
# 28      29    Cindy Nelson     Brian Baker
# 29      30    Derek Carter     Brian Baker
# 30      31   Emma Mitchell     Brian Baker
# 31      32     Felix Perez     Brian Baker
# 32      33    Gina Roberts     Brian Baker
# 33      34    Henry Turner     Brian Baker
# 34      35    Ivy Phillips     Brian Baker
# 35      36  James Campbell             NaN
# 36      37    Kelly Parker  James Campbell
# 37      38      Liam Evans    Kelly Parker
# 38      39     Mia Edwards    Kelly Parker
# 39      40    Noah Collins    Kelly Parker
# 40      41   Oscar Stewart    Kelly Parker
# 41      42    Paula Morris             NaN

# %% [markdown]
# **Expected output:** ALL employees now appear. The directors (Alice Chen, Iris Taylor, Nathan Harris, etc.) will have `NULL` in the manager_name column because their `manager_id` is NULL and no match was found.
#
# **Key difference:** INNER JOIN self-join lost the directors. LEFT JOIN self-join kept them with NULL managers. Choose based on whether you want to include top-level employees.

# %% [markdown]
# ## Multi-Table Join — employees → departments → sales → products
#
# Real analytical queries often join 3 or more tables. The golden rule: **build step by step**, verifying each join before adding the next.
#
# **The chain:**
# 1. `employees` → `departments` (via department_id = dept_id)
# 2. + `sales` (via emp_id = employee_id)
# 3. + `products` (via product_id = product_id)
#
# **Business question:** "Which employees sold which products, in which departments, and how much revenue did they generate?"

# %% [markdown]
# ### Step 1: employees + departments

# %%
# Step 1: Join employees with their departments
run_query("""
    SELECT 
        e.emp_id,
        e.first_name || ' ' || e.last_name AS employee_name,
        d.dept_name
    FROM company.employees e
    LEFT JOIN company.departments d 
        ON e.department_id = d.dept_id
    ORDER BY e.emp_id
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id   employee_name        dept_name
# 0        1      Alice Chen      Engineering
# 1        2    Bob Martinez      Engineering
# 2        3   Carol Johnson      Engineering
# 3        4       David Kim      Engineering
# 4        5       Eva Patel      Engineering
# 5        6    Frank Wilson      Engineering
# 6        7       Grace Lee      Engineering
# 7        8      Hank Brown      Engineering
# 8        9     Iris Taylor  Human Resources
# 9       10   Jack Anderson  Human Resources
# 10      11    Karen Thomas  Human Resources
# 11      12     Leo Jackson  Human Resources
# 12      13     Maria White  Human Resources
# 13      14   Nathan Harris          Finance
# 14      15    Olivia Clark          Finance
# 15      16     Peter Lewis          Finance
# 16      17    Quinn Walker          Finance
# 17      18     Rachel Hall          Finance
# 18      19       Sam Allen          Finance
# 19      20      Tina Young          Finance
# 20      21        Uma King        Marketing
# 21      22   Victor Wright        Marketing
# 22      23     Wendy Lopez        Marketing
# 23      24     Xavier Hill        Marketing
# 24      25      Yara Scott        Marketing
# 25      26      Zane Green        Marketing
# 26      27       Amy Adams            Sales
# 27      28     Brian Baker            Sales
# 28      29    Cindy Nelson            Sales
# 29      30    Derek Carter            Sales
# 30      31   Emma Mitchell            Sales
# 31      32     Felix Perez            Sales
# 32      33    Gina Roberts            Sales
# 33      34    Henry Turner            Sales
# 34      35    Ivy Phillips            Sales
# 35      36  James Campbell       Operations
# 36      37    Kelly Parker       Operations
# 37      38      Liam Evans       Operations
# 38      39     Mia Edwards       Operations
# 39      40    Noah Collins       Operations
# 40      41   Oscar Stewart       Operations
# 41      42    Paula Morris              NaN

# %% [markdown]
# **Expected output:** All employees with their department names. This is the foundation — every subsequent join will build on this.

# %% [markdown]
# ### Step 2: + sales (now we have employees + departments + sales)

# %%
# Step 2: Add sales data
run_query("""
    SELECT 
        e.emp_id,
        e.first_name || ' ' || e.last_name AS employee_name,
        d.dept_name,
        s.sale_id,
        s.quantity,
        s.sale_date
    FROM company.employees e
    LEFT JOIN company.departments d 
        ON e.department_id = d.dept_id
    LEFT JOIN company.sales s 
        ON e.emp_id = s.employee_id
    ORDER BY e.emp_id, s.sale_date
    LIMIT 30
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id  employee_name        dept_name  sale_id  quantity   sale_date
# 0        1     Alice Chen      Engineering      NaN       NaN        None
# 1        2   Bob Martinez      Engineering      NaN       NaN        None
# 2        3  Carol Johnson      Engineering    110.0       1.0  2025-02-10
# 3        4      David Kim      Engineering    111.0       1.0  2025-03-15
# 4        5      Eva Patel      Engineering    112.0       1.0  2025-04-20
# 5        6   Frank Wilson      Engineering    113.0       2.0  2025-05-25
# 6        7      Grace Lee      Engineering    114.0       1.0  2025-06-30
# 7        8     Hank Brown      Engineering      NaN       NaN        None
# 8        9    Iris Taylor  Human Resources      NaN       NaN        None
# 9       10  Jack Anderson  Human Resources      NaN       NaN        None
# 10      11   Karen Thomas  Human Resources    115.0       3.0  2025-07-05
# 11      12    Leo Jackson  Human Resources    116.0       1.0  2025-08-10
# 12      13    Maria White  Human Resources    117.0       1.0  2025-09-15
# 13      14  Nathan Harris          Finance    118.0       2.0  2025-10-20
# 14      15   Olivia Clark          Finance    119.0       1.0  2025-11-25
# 15      16    Peter Lewis          Finance      NaN       NaN        None
# 16      17   Quinn Walker          Finance      NaN       NaN        None
# 17      18    Rachel Hall          Finance      NaN       NaN        None
# 18      19      Sam Allen          Finance      NaN       NaN        None
# 19      20     Tina Young          Finance      NaN       NaN        None
# 20      21       Uma King        Marketing      NaN       NaN        None
# 21      22  Victor Wright        Marketing    120.0       1.0  2025-03-05
# 22      23    Wendy Lopez        Marketing    121.0       1.0  2025-05-10
# 23      24    Xavier Hill        Marketing    122.0       1.0  2025-07-15
# 24      25     Yara Scott        Marketing    123.0       1.0  2025-09-20
# 25      26     Zane Green        Marketing    124.0       1.0  2025-11-30
# 26      27      Amy Adams            Sales      NaN       NaN        None
# 27      28    Brian Baker            Sales      NaN       NaN        None
# 28      29   Cindy Nelson            Sales      1.0       2.0  2025-01-05
# 29      29   Cindy Nelson            Sales      2.0       1.0  2025-01-08

# %% [markdown]
# **Expected output:** Employees with their department, and one row per sale. If an employee made multiple sales, their name appears multiple times (one row per sale). Employees with no sales will have NULL in sale_id, quantity, and sale_date.
#
# **Notice the LEFT JOIN chain:** We use LEFT JOIN for both joins so we don't lose employees who haven't made sales yet. If we used INNER JOIN on sales, only employees with at least one sale would appear.

# %% [markdown]
# ### Step 3: + products (the complete 4-table join)

# %%
# Step 3: Add products for the full picture
run_query("""
    SELECT 
        e.emp_id,
        e.first_name || ' ' || e.last_name AS employee_name,
        d.dept_name,
        p.product_name,
        p.category,
        s.quantity,
        p.unit_price,
        s.quantity * p.unit_price AS revenue,
        s.sale_date
    FROM company.employees e
    LEFT JOIN company.departments d 
        ON e.department_id = d.dept_id
    LEFT JOIN company.sales s 
        ON e.emp_id = s.employee_id
    LEFT JOIN company.products p 
        ON s.product_id = p.product_id
    ORDER BY revenue DESC NULLS LAST
    LIMIT 30
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     emp_id  employee_name  dept_name               product_name  category  \
# 0       30   Derek Carter      Sales     Implementation Package  Services
# 1       34   Henry Turner      Sales     Implementation Package  Services
# 2       32    Felix Perez      Sales     Implementation Package  Services
# 3       31  Emma Mitchell      Sales     Implementation Package  Services
# 4       34   Henry Turner      Sales     Data Migration Service  Services
# 5       34   Henry Turner      Sales     Premium Support Annual  Services
# 6       29   Cindy Nelson      Sales     Premium Support Annual  Services
# 7       23    Wendy Lopez  Marketing     Implementation Package  Services
# 8       31  Emma Mitchell      Sales  Data Engineering Bootcamp  Training
# 9       32    Felix Perez      Sales     Implementation Package  Services
# 10      30   Derek Carter      Sales     Implementation Package  Services
# 11      31  Emma Mitchell      Sales     Implementation Package  Services
# 12      30   Derek Carter      Sales         Custom Integration  Services
# 13      34   Henry Turner      Sales         Custom Integration  Services
# 14      33   Gina Roberts      Sales         Custom Integration  Services
# 15      24    Xavier Hill  Marketing         Custom Integration  Services
# 16      33   Gina Roberts      Sales         Custom Integration  Services
# 17      32    Felix Perez      Sales         Custom Integration  Services
# 18      31  Emma Mitchell      Sales           Server Rack X200  Hardware
# 19      34   Henry Turner      Sales           Server Rack X200  Hardware
# 20      33   Gina Roberts      Sales  Data Engineering Bootcamp  Training
# 21      33   Gina Roberts      Sales  Data Engineering Bootcamp  Training
# 22      34   Henry Turner      Sales     Data Migration Service  Services
# 23      29   Cindy Nelson      Sales     Data Migration Service  Services
# 24      33   Gina Roberts      Sales     Data Migration Service  Services
# 25      30   Derek Carter      Sales     Data Migration Service  Services
# 26      25     Yara Scott  Marketing     Data Migration Service  Services
# 27      31  Emma Mitchell      Sales     Premium Support Annual  Services
# 28      30   Derek Carter      Sales     Premium Support Annual  Services
# 29      30   Derek Carter      Sales     Premium Support Annual  Services
#
#     quantity  unit_price   revenue   sale_date
# 0          2    15000.00  30000.00  2025-07-18
# 1          2    15000.00  30000.00  2025-11-12
# 2          2    15000.00  30000.00  2025-12-28
# 3          2    15000.00  30000.00  2025-05-22
# 4          2     9500.00  19000.00  2025-12-20
# 5          2     8500.00  17000.00  2025-08-22
# 6          2     8500.00  17000.00  2025-10-25
# 7          1    15000.00  15000.00  2025-05-10
# 8          3     5000.00  15000.00  2025-12-12
# 9          1    15000.00  15000.00  2025-03-25
# 10         1    15000.00  15000.00  2025-01-15
# 11         1    15000.00  15000.00  2025-09-22
# 12         1    12000.00  12000.00  2025-11-18
# 13         1    12000.00  12000.00  2025-02-18
# 14         1    12000.00  12000.00  2025-07-08
# 15         1    12000.00  12000.00  2025-07-15
# 16         1    12000.00  12000.00  2025-09-08
# 17         1    12000.00  12000.00  2025-05-05
# 18         2     5499.99  10999.98  2025-11-22
# 19         2     5499.99  10999.98  2025-10-02
# 20         2     5000.00  10000.00  2025-10-18
# 21         2     5000.00  10000.00  2025-06-18
# 22         1     9500.00   9500.00  2025-08-01
# 23         1     9500.00   9500.00  2025-03-15
# 24         1     9500.00   9500.00  2025-05-28
# 25         1     9500.00   9500.00  2025-10-08
# 26         1     9500.00   9500.00  2025-09-20
# 27         1     8500.00   8500.00  2025-04-12
# 28         1     8500.00   8500.00  2025-12-08
# 29         1     8500.00   8500.00  2025-06-08

# %% [markdown]
# **Expected output:** A rich analytical result showing employee, department, product sold, quantity, price, calculated revenue, and date. The `NULLS LAST` in ORDER BY ensures employees with no sales appear at the bottom.
#
# **Revenue calculation:** `s.quantity * p.unit_price AS revenue` — this computes revenue per sale line item directly in SQL. No need for Python/pandas post-processing!
#
# **Building multi-table joins tip:** Always verify each step. If Step 2 produces unexpected results, adding Step 3 will only compound the problem.

# %%
# Bonus: Revenue summary by department
run_query("""
    SELECT 
        d.dept_name,
        COUNT(s.sale_id) AS total_sales,
        SUM(s.quantity * p.unit_price) AS total_revenue,
        ROUND(AVG(s.quantity * p.unit_price), 2) AS avg_sale_value
    FROM company.departments d
    LEFT JOIN company.employees e 
        ON e.department_id = d.dept_id
    LEFT JOIN company.sales s 
        ON e.emp_id = s.employee_id
    LEFT JOIN company.products p 
        ON s.product_id = p.product_id
    GROUP BY d.dept_name
    ORDER BY total_revenue DESC NULLS LAST
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#          dept_name  total_sales  total_revenue  avg_sale_value
# 0            Sales          109      629748.63         5777.51
# 1        Marketing            5       45899.99         9180.00
# 2  Human Resources            3       13000.00         4333.33
# 3       Operations            4       11749.99         2937.50
# 4      Engineering            5        3599.94          719.99
# 5          Finance            2        2299.97         1149.99

# %% [markdown]
# **Expected output:** A summary table with one row per department showing total number of sales, total revenue, and average sale value. Departments with no sales show NULL. This combines everything you've learned: multi-table joins, aggregation, and sorting.
#
# **GROUP BY reminder:** When you aggregate (COUNT, SUM, AVG), every non-aggregated column in SELECT must appear in GROUP BY.

# %% [markdown]
# ## Try It Yourself Exercises
#
# Now it's your turn! Try each exercise before revealing the solution. Use what you've learned about different JOIN types.

# %% [markdown]
# ### Exercise 1: Find employees who have never made a sale
#
# Use a `LEFT JOIN` between `employees` and `sales`, then filter to find employees with no sales records. Show their name, department, and hire_date.
#
# **Hint:** LEFT JOIN employees to sales, then WHERE the sale column IS NULL.
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# ```sql
# SELECT
#     e.first_name || ' ' || e.last_name AS employee_name,
#     d.dept_name,
#     e.hire_date
# FROM company.employees e
# LEFT JOIN company.departments d
#     ON e.department_id = d.dept_id
# LEFT JOIN company.sales s
#     ON e.emp_id = s.employee_id
# WHERE s.sale_id IS NULL
# ORDER BY e.last_name;
# ```
#
# **Expected output:** All employees who have zero sales records. They will have their name, department, and hire_date, but no sales. This is useful for identifying employees who might need sales training or who are in non-sales roles.
# </details>

# %%
# Your solution here:
run_query("""
    
""")
# Out:
# /tmp/ipykernel_20614/2533838494.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Your solution here:
# ----> 2 run_query("""
#       3
#       4 """)
#
# Cell In[9], line 14, in run_query(sql)
#      10     try:
#      11         df = pd.read_sql_query(sql, conn)
#      12         return df
#      13     finally:
# ---> 14         conn.close()
#
# File ~/Desktop/projects/DataEngineeringLLM/module-02-sql-elt-pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~/Desktop/projects/DataEngineeringLLM/module-02-sql-elt-pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~/Desktop/projects/DataEngineeringLLM/module-02-sql-elt-pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2700 cur = self.con.cursor()
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#    2704 except Error as exc:
#
# ProgrammingError: can't execute an empty query

# %% [markdown]
# ### Exercise 2: Show each product and who sold it
#
# Join `products` to `sales` to `employees` to see which employee sold which product. Include the product name, employee name, quantity, and sale date. Order by most recent sales first.
#
# **Hint:** Start FROM products, LEFT JOIN sales, then LEFT JOIN employees. Use LEFT JOIN so products that have never been sold still appear.
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# ```sql
# SELECT
#     p.product_name,
#     p.category,
#     e.first_name || ' ' || e.last_name AS sold_by,
#     s.quantity,
#     s.sale_date
# FROM company.products p
# LEFT JOIN company.sales s
#     ON p.product_id = s.product_id
# LEFT JOIN company.employees e
#     ON s.employee_id = e.emp_id
# ORDER BY s.sale_date DESC NULLS LAST;
# ```
#
# **Expected output:** All products appear, even those never sold. For sold products, you'll see the employee name, quantity, and date. Products that were never sold have NULL in the employee, quantity, and date columns.
# </details>

# %%
# Your solution here:
run_query("""
    
""")

# %% [markdown]
# ### Exercise 3: Find departments with no employees
#
# Use a `LEFT JOIN` (or `RIGHT JOIN`) to find departments that currently have no employees assigned to them.
#
# **Hint:** Start FROM departments, LEFT JOIN employees on department_id = dept_id, then WHERE emp_id IS NULL.
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# ```sql
# SELECT
#     d.dept_name,
#     d.location
# FROM company.departments d
# LEFT JOIN company.employees e
#     ON e.department_id = d.dept_id
# WHERE e.emp_id IS NULL;
# ```
#
# **Expected output:** Any departments that have zero employees assigned. This might be empty (if all departments have people) or might list one or two departments. This is a useful organizational report — "empty departments" that may need attention.
# </details>

# %%
# Your solution here:
run_query("""
    
""")
